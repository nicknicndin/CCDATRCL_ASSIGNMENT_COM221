# %% [markdown]
# <a href="https://colab.research.google.com/github/nicknicndin/CCDATRCL_ASSIGNMENT_COM221/blob/main/Copy_of_exercise7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercise 7

# %%
class Node:
    def __init__(self, item):
        self.left = None
        self.right = None
        self.val = item

# %%
def evaluateExpressionTree(root):

    # empty tree
    if root is None:
        return 0

    # leaf node
    if root.left is None and root.right is None:
        return int(root.val)

    # evaluate left tree
    left_sum = evaluateExpressionTree(root.left)

    # evaluate right tree
    right_sum = evaluateExpressionTree(root.right)

    # check which operation to apply
    if root.val == '+':
        return left_sum + right_sum

    elif root.val == '-':
        return left_sum - right_sum

    elif root.val == '*':
        return left_sum * right_sum

    else:
        return left_sum / right_sum

# %%
def inorder(root):

    if root:
        # Traverse left
        inorder(root.left)
        # Traverse root
        print(str(root.val) + "->", end='')
        # Traverse right
        inorder(root.right)

# %% [markdown]
# #### 1. Construct a binary expression tree
#
#
# - Use the evaluateExpressionTree method to get the result of the expression
# - Use the inorder method to traverse the tree
#
# $$ (8 + 4) * (7 - 9) $$

# %%
# put your answer here


node1 = Node("+")
node2 = Node("*")
node3 = Node("-")
node4 = Node("8")
node5 = Node("4")
node6 = Node("7")
node7 = Node("9")

root = node2
root.left = node1
root.left.left = node4
root.left.right = node5
root.right = node3
root.right.left = node6
root.right.right = node7

evaluateExpressionTree(root)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-45b39886be2c> in <cell line: 13>()
#      11
#      12 root = node2
# ---> 13 root.left.left = node4
#      14 root.left = node1
#      15 root.left.right = node5
#
# AttributeError: 'NoneType' object has no attribute 'left'

# %%
inorder(root)
# Out:
# 8->+->4->*->7->-->9->

# %% [markdown]
# #### 2. Construct a binary expression tree
#
# - Use the evaluateExpressionTree method to get the result of the expression
# - Use the inorder method to traverse the tree
#
# $$ 5 / 8 + 3 - 6 * 1 $$

# %%
# put your answer here
node1 = Node("-")
node2 = Node("+")
node3 = Node("*")
node4 = Node("/")
node5 = Node("5")
node6 = Node("8")
node7 = Node("3")
node8 = Node("6")
node9 = Node("1")

root = node1
root.left = node2
root.left.left =

# %% [markdown]
# #### 3. Construct a binary expression tree
#
# - Use the evaluateExpressionTree method to get the result of the expression
# - Use the inorder method to traverse the tree
#
# $$ ((2 + 5) / 3)- (3 + 8) $$

# %%
# put your answer here
